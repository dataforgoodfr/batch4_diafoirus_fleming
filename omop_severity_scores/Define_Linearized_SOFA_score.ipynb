# %% [markdown]
# # Linearized SOFA score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go

# MatPlotlib
import matplotlib.pyplot as plt
from matplotlib import pylab

# %%
def graph(formula, x_range):  
    x = np.array(x_range)  
    y = eval(formula)
    plt.plot(x, y)  
    plt.show()

# %% [markdown]
# # Compute linearized parametres

# %% [markdown]
# ## Oxygen saturation in Arterial blood

# %% [markdown]
# ### Original score

# %%
x = [0,100,200,300,400,500] 
y = [4,4,3,2,1,0]

plt.step(x, y)
plt.show()

# %% [markdown]
# ### Linearized score

# %%
y2=graph('-0.01*x+4', range(0, 400))

# %%
"""     if(paO2FiO2<400):
            sofa_score += -0.01*paO2FiO2+4
"""
# Out:
# '     if(paO2FiO2<400):\n            sofa_score += -0.01*paO2FiO2+4\n'

# %%
x = [0,100,200,300,400,500] 
y = [4,4,3,2,1,0]

t = np.arange(0,400)

plt.step(x, y)
plt.plot(t,-0.01*t+4)
plt.show()

# %% [markdown]
# ## Platelets [#/volume] in Blood by Automated count

# %% [markdown]
# ### Original score

# %%
x = [0,20,50,100,150,200] 
y = [4,4,3,2,1,0]

plt.step(x, y)
plt.show()

# %% [markdown]
# #### test deg 1

# %%
x = [0,20,50,100,150] 
y = [4,3,2,1,0]
z = np.polyfit(x, y, 1)
f = np.poly1d(z)
print (f)
# Out:
#
# -0.02547 x + 3.63

# %%
x = [0,20,50,100,150,200] 
y = [4,4,3,2,1,0]

t = np.arange(0,150)

plt.step(x, y)
plt.plot(t,-0.02547*t+3.63)
plt.show()

# %% [markdown]
# #### test deg 2

# %%
x = [0,20,50,100,150] 
y = [4,3,2,1,0]
z = np.polyfit(x, y, 2)
f = np.poly1d(z)
print (f)
# Out:
#            2
# 0.0001005 x - 0.04057 x + 3.885

# %%
x = [0,20,50,100,150,200] 
y = [4,4,3,2,1,0]

t = np.arange(0,150)

plt.step(x, y)
plt.plot(t,0.0001*t*t-0.0457*t+3.885)
plt.show()

# %% [markdown]
# These two solutions doesn't feet so we try multiples lines

# %%
def multiplelines (x):
    
    if x<20:
        y=-0.05*x+4
    elif x<50:
        y=-x/30+11/3
    elif x<150:
        y=-0.02*x+3
    return y

# %%
x = [0,20,50,100,150,200] 
y = [4,4,3,2,1,0]

t = np.arange(0,150)
y2 = []
for i in t:
    y2.append(multiplelines(i))

plt.step(x, y)
plt.plot(t,y2)
plt.show()

# %%
"""     if(platelets<20):
            sofa_score+=-0.05*platelets+4
        elif(platelets<50):
            sofa_score+=-platelets/30+11/3
        elif(platelets<150):
            sofa_score+=-0.02*platelets+3 
"""
# Out:
# '     if(platelets<20):\n            sofa_score+=-0.05*platelets+4\n        elif(platelets<50):\n            sofa_score+=-platelets/30+11/3\n        elif(platelets<150):\n            sofa_score+=-0.02*platelets+3 \n'

# %% [markdown]
# ## Total Bilirubin serum/plasma

# %% [markdown]
# #### Original score

# %%
x = [0,20,33,102,204,250] 
y = [4,4,3,2,1,0]

plt.step(x, y)
plt.show()

# %%
def multiplelines (x):
    y=0
    if x<20:
        y=-0.05*x+4
    elif x<33:
        y=-x/13+59/13
    elif x<102:
        y=-x/69+57/23
    elif x<204:
        y=-x/102+2
    return y

# %%
x = [0,20,33,102,204,250] 
y = [4,4,3,2,1,0]

t = np.arange(0,250)
y2 = []
for i in t:
    y2.append(multiplelines(i))

plt.step(x, y)
plt.plot(t,y2)
plt.show()

# %%
"""     if(bilirubin<20):
            sofa_score+=-0.05*bilirubin+4
        elif(bilirubin<33):
            sofa_score+=-bilirubin/13+59/13
        elif(bilirubin<102):
            sofa_score+=-bilirubin/69+57/23 
        elif(bilirubin<204):
            sofa_score+=-bilirubin/102+2 
"""
# Out:
# '     if(bilirubin<20):\n            sofa_score+=-0.05*bilirubin+4\n        elif(bilirubin<33):\n            sofa_score+=-bilirubin/13+59/13\n        elif(bilirubin<102):\n            sofa_score+=-bilirubin/69+57/23 \n        elif(bilirubin<204):\n            sofa_score+=-bilirubin/102+2 \n'

# %% [markdown]
# ## Glasgow coma scale

# %% [markdown]
# ### Original socre

# %%
x = [0,6,9,12,14,18] 
y = [4,4,3,2,1,0]

plt.step(x, y)
plt.show()

# %%
def multiplelines (x):
    y=0
    if x<6:
        y=-x/6+4
    elif x<12:
        y=-x/3+5
    elif x<14:
        y=-x/2+7
    return y

# %%
x = [0,6,9,12,14,18] 
y = [4,4,3,2,1,0]

t = np.arange(0,18)
y2 = []
for i in t:
    y2.append(multiplelines(i))

plt.step(x, y)
plt.plot(t,y2)
plt.show()

# %%
"""     if(glasgow_coma_score<6):
            sofa_score+=-glasgow_coma_score/6+4
        elif(glasgow_coma_score<12):
            sofa_score+=-glasgow_coma_score/3+5
        elif(glasgow_coma_score<14):
            sofa_score+=-glasgow_coma_score/2+7
"""
# Out:
# '     if(glasgow_coma_score<6):\n            sofa_score+=-glasgow_coma_score/6+4\n        elif(glasgow_coma_score<12):\n            sofa_score+=-glasgow_coma_score/3+5\n        elif(glasgow_coma_score<14):\n            sofa_score+=-glasgow_coma_score/2+7\n'

# %% [markdown]
# ## Creatinine serum/plasma

# %% [markdown]
# ### Original score

# %%
x = [0,19,34,49,50,70] 
y = [1,1,2,3,4,4]

plt.step(x, y)
plt.show()

# %%
def multiplelines (x):
    y=4
    if x<=19:
        y=x/19+1
    elif x<=49:
        y=x/15+11/15
    return y

# %%
x = [0,19,34,49,50,70] 
y = [1,1,2,3,4,4]

t = np.arange(0,70)
y2 = []
for i in t:
    y2.append(multiplelines(i))

plt.step(x, y)
plt.plot(t,y2)
plt.show()

# %%
"""
        if(creatinine<=19):
            sofa_score+=creatinine/19+1
        elif(creatinine<=49):
            sofa_score+=creatinine/15+11/15
        elif(creatinine>=50):
            sofa_score+=4

"""
# Out:
# '\n        if(creatinine<=19):\n            sofa_score+=creatinine/19+1\n        elif(creatinine<=49):\n            sofa_score+=creatinine/15+11/15\n        elif(creatinine>=50):\n            sofa_score+=4\n\n'

# %% [markdown]
# # Final Algorithm

# %%
def compute_Lsofa_score(row):
    """
    Compute the linearized SOFA score

    Args:
        #measurement                concept_id
        paO2/FiO2 (float):          4233883 
        platelets (float):          3024929
        bilirubin (float):          3024128
        map (float):                3027598         
        glasgow-coma_score (float): 3032652
        creatinine (float):         3016723 

        #drugs
        dopamine (float):           1337860
        epinephrine (float):        1343916 / 1344056
        norepinephrine (float):     1321341 / 1321364
        dobutamine (float):         1337720

    Returns:
        Lsofa_score (int): Linearized SOFA score 
    """
   
    Lsofa_score = 0 

    if 'Oxygen saturation in Arterial blood' in row:

        paO2FiO2= row['Oxygen saturation in Arterial blood']
    
        if(paO2FiO2<400):
            Lsofa_score += -0.01*paO2FiO2+4

    if 'Platelets [#/volume] in Blood by Automated count' in row:

        platelets=row['Platelets [#/volume] in Blood by Automated count']

        if(platelets<20):
            Lsofa_score+=-0.05*platelets+4
        elif(platelets<50):
            Lsofa_score+=-platelets/30+11/3
        elif(platelets<150):
            Lsofa_score+=-0.02*platelets+3  

    if 'Total Bilirubin serum/plasma' in row:

        bilirubin=row['Total Bilirubin serum/plasma']
        
        if(bilirubin<20):
            Lsofa_score+=-0.05*bilirubin+4
        elif(bilirubin<33):
            Lsofa_score+=-bilirubin/13+59/13
        elif(bilirubin<102):
            Lsofa_score+=-bilirubin/69+57/23 
        elif(bilirubin<204):
            Lsofa_score+=-bilirubin/102+2 
            
    if 'Glasgow coma scale' in row:

        if(glasgow_coma_score<6):
            Lsofa_score+=-glasgow_coma_score/6+4
        elif(glasgow_coma_score<12):
            Lsofa_score+=-glasgow_coma_score/3+5
        elif(glasgow_coma_score<14):
            Lsofa_score+=-glasgow_coma_score/2+7
            
    if 'Creatinine serum/plasma' in row:

        creatinine=row['Creatinine serum/plasma']    

        if(creatinine<=19):
            Lsofa_score+=creatinine/19+1
        elif(creatinine<=49):
            Lsofa_score+=creatinine/15+11/15
        elif(creatinine>=50):
            Lsofa_score+=4
            
            

    if 'Dopamine' in row:

        dopamine=row['Dopamine']      

        if(dopamine>15):
            Lsofa_score+=4 
        elif(dopamine>5):
            Lsofa_score+=3
        elif(dopamine<=5):
            Lsofa_score+=2
    elif 'Norepinephrine' in row:

        norepinephrine=row['Norepinephrine']

        if(norepinephrine>0.1):
            Lsofa_score+=4
        else:
            Lsofa_score+=3

    elif 'Epinephrine' in row:

        epinephrine=row['Epinephrine']

        if(epinephrine>0.1):
            Lsofa_score+=4
        else:
            Lsofa_score+=3

    elif 'Dobutamine' in row:

        dobutamine=row['Dobutamine']

        if(dobutamine>0):
            Lsofa_score+=2

    elif 'Mean blood pressure' in row:

        mbp=row['Mean blood pressure']

        if(mbp<70):
            Lsofa_score+=1


    

    return Lsofa_score
