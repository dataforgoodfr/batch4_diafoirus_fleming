# %% [markdown]
# # EDA of the MIMIC dataset
#
# In order to connect to the full database, you will need to install the [pymonetdb](https://pypi.python.org/pypi/pymonetdb) package. You can do this in your terminal with 'conda install pymonetdb' (if you have Anaconda, use this one as it is more stable) or 'pip install pymonetdb'.
#
# Last step before running the notebook: you need access credentials to this database and replace 'fleming' and the specified password by the ones you were provided with.
#
# Access are only available to people that passed the CITI “Data or Specimens Only Research” and completed the different steps to be granted an access. If you wish to request an access, please refer to this [page](https://mimic.physionet.org/gettingstarted/access/)

# %%
# Get your credentials
import numpy as np
omop_login = np.load('full_omop_login.npy').item()

# Open a connection to OMOP
from fleming_lib.tools import connect_to_omop
conn = connect_to_omop(login_dict=omop_login)

# Get ready for SQL query processing
import pandas as pd

# %% [markdown]
# As a golden rule, DO NOT retrieve entire tables unless it's absolutely necessary!!
#
# Stats can be computed more efficiently through SQL directly (the database is on a cluster that is most likely way more powerful than your local machine). Downloading of entire tables should only occur for model training and testing ideally.

# %% [markdown]
# ## Person table
# Information related to each patient

# %%
pd.read_sql_query('select * from person limit 10;', conn)
# Out:
#    person_id  gender_concept_id  year_of_birth  month_of_birth  day_of_birth  \
# 0   62063589               8507           2138               7            17
# 1   62063590               8507           2025               4            11
# 2   62063591               8532           2143               5            12
# 3   62063592               8507           2103               2             2
# 4   62063593               8532           2109               6            21
# 5   62063594               8532           2121               5            23
# 6   62063595               8507           2117              11            20
# 7   62063596               8507           2108               1            26
# 8   62063597               8532           2103               6            28
# 9   62063598               8532           2128               2            22
#
#   birth_datetime  race_concept_id  ethnicity_concept_id location_id  \
# 0     2138-07-17             8515                     0        None
# 1     2025-04-11             8527                     0        None
# 2     2143-05-12             8527                     0        None
# 3     2103-02-02             8515                     0        None
# 4     2109-06-21             8527                     0        None
# 5     2121-05-23             8527                     0        None
# 6     2117-11-20             8527                     0        None
# 7     2108-01-26          4218674                     0        None
# 8     2103-06-28         38003599                     0        None
# 9     2128-02-22             8527                     0        None
#
#   provider_id care_site_id person_source_value gender_source_value  \
# 0        None         None                None                   M
# 1        None         None                None                   M
# 2        None         None                None                   F
# 3        None         None                None                   M
# 4        None         None                None                   F
# 5        None         None                None                   F
# 6        None         None                None                   M
# 7        None         None                None                   M
# 8        None         None                None                   F
# 9        None         None                None                   F
#
#   gender_source_concept_id       race_source_value race_source_concept_id  \
# 0                     None                   ASIAN                   None
# 1                     None                   WHITE                   None
# 2                     None                   WHITE                   None
# 3                     None                   ASIAN                   None
# 4                     None                   WHITE                   None
# 5                     None                   WHITE                   None
# 6                     None                   WHITE                   None
# 7                     None   UNKNOWN/NOT SPECIFIED                   None
# 8                     None  BLACK/AFRICAN AMERICAN                   None
# 9                     None                   WHITE                   None
#
#   ethnicity_source_value ethnicity_source_concept_id
# 0                   None                        None
# 1                   None                        None
# 2                   None                        None
# 3                   None                        None
# 4                   None                        None
# 5                   None                        None
# 6                   None                        None
# 7                   None                        None
# 8                   None                        None
# 9                   None                        None

# %% [markdown]
# Ethnicity can be aggregated apparently, and we would need the age of patient when they were first processed by the hospital

# %%
query = """
select 
    p.race_source_value as ethnicity, p.gender_source_value as gender, 
    avg((v.first_visit_date - p.birth_datetime)/365.25) as avg_age,
    count(0) as count 
from 
    person p
    
    left outer join

    (select 
        person_id, min(visit_start_date) as first_visit_date
    from
        visit_occurrence
    group by 
        person_id) v
    
    on p.person_id = v.person_id
    
group by
    p.race_source_value, p.gender_source_value
order by
    p.race_source_value, p.gender_source_value    
    ;"""
#query = "select datepart(yyyy, birth_datetime) from person limit 5;"
person_age_by_ethnicity_gender = pd.read_sql_query(query, conn)
person_age_by_ethnicity_gender
# Out:
#                                             ethnicity gender     avg_age  \
# 0                       AMERICAN INDIAN/ALASKA NATIVE      F   33.774500
# 1                       AMERICAN INDIAN/ALASKA NATIVE      M   14.740480
# 2   AMERICAN INDIAN/ALASKA NATIVE FEDERALLY RECOGN...      F   60.501000
# 3   AMERICAN INDIAN/ALASKA NATIVE FEDERALLY RECOGN...      M   43.835000
# 4                                               ASIAN      F   32.566360
# 5                                               ASIAN      M   32.689960
# 6                                ASIAN - ASIAN INDIAN      F   66.120250
# 7                                ASIAN - ASIAN INDIAN      M   57.036081
# 8                                   ASIAN - CAMBODIAN      F   63.049750
# 9                                   ASIAN - CAMBODIAN      M   47.545167
# 10                                    ASIAN - CHINESE      F   56.832010
# 11                                    ASIAN - CHINESE      M   56.453319
# 12                                   ASIAN - FILIPINO      F   77.334364
# 13                                   ASIAN - FILIPINO      M   48.639250
# 14                                   ASIAN - JAPANESE      F   52.125000
# 15                                   ASIAN - JAPANESE      M  188.497500
# 16                                     ASIAN - KOREAN      F   46.891571
# 17                                     ASIAN - KOREAN      M   60.970750
# 18                                      ASIAN - OTHER      F   21.613000
# 19                                      ASIAN - OTHER      M   48.321800
# 20                                       ASIAN - THAI      M   56.907667
# 21                                 ASIAN - VIETNAMESE      F   70.215071
# 22                                 ASIAN - VIETNAMESE      M   49.583926
# 23                                      BLACK/AFRICAN      F   47.653059
# 24                                      BLACK/AFRICAN      M   48.932600
# 25                             BLACK/AFRICAN AMERICAN      F   54.096100
# 26                             BLACK/AFRICAN AMERICAN      M   45.179972
# 27                                 BLACK/CAPE VERDEAN      F   54.610195
# 28                                 BLACK/CAPE VERDEAN      M   57.905329
# 29                                      BLACK/HAITIAN      F   70.695079
# ..                                                ...    ...         ...
# 51                       HISPANIC/LATINO - SALVADORAN      F   47.343000
# 52                       HISPANIC/LATINO - SALVADORAN      M   44.076200
# 53                                     MIDDLE EASTERN      F   78.932556
# 54                                     MIDDLE EASTERN      M   52.249632
# 55                               MULTI RACE ETHNICITY      F   53.843020
# 56                               MULTI RACE ETHNICITY      M   42.371950
# 57          NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER      F   51.417571
# 58          NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER      M   38.625000
# 59                                              OTHER      F   44.207101
# 60                                              OTHER      M   44.370024
# 61                         PATIENT DECLINED TO ANSWER      F   50.586856
# 62                         PATIENT DECLINED TO ANSWER      M   51.822450
# 63                                         PORTUGUESE      F   53.894375
# 64                                         PORTUGUESE      M   55.820150
# 65                                     SOUTH AMERICAN      F   51.348750
# 66                                     SOUTH AMERICAN      M   39.629250
# 67                                   UNABLE TO OBTAIN      F   73.469511
# 68                                   UNABLE TO OBTAIN      M   61.472920
# 69                              UNKNOWN/NOT SPECIFIED      F   70.368658
# 70                              UNKNOWN/NOT SPECIFIED      M   60.507435
# 71                                              WHITE      F   72.295292
# 72                                              WHITE      M   60.924719
# 73                                  WHITE - BRAZILIAN      F   45.002550
# 74                                  WHITE - BRAZILIAN      M   43.086455
# 75                           WHITE - EASTERN EUROPEAN      F   62.820000
# 76                           WHITE - EASTERN EUROPEAN      M   78.855467
# 77                             WHITE - OTHER EUROPEAN      F   68.949161
# 78                             WHITE - OTHER EUROPEAN      M   61.438684
# 79                                    WHITE - RUSSIAN      F  120.492000
# 80                                    WHITE - RUSSIAN      M   89.267783
#
#     count
# 0      20
# 1      25
# 2       1
# 3       1
# 4     572
# 5     732
# 6      20
# 7      37
# 8       4
# 9       6
# 10    104
# 11    119
# 12     11
# 13      4
# 14      5
# 15      2
# 16      7
# 17      4
# 18      5
# 19     10
# 20      3
# 21     14
# 22     27
# 23     17
# 24     15
# 25   1914
# 26   1671
# 27     77
# 28     82
# 29     38
# ..    ...
# 51      4
# 52     10
# 53      9
# 54     19
# 55     51
# 56     60
# 57      7
# 58      8
# 59    495
# 60    761
# 61    209
# 62    289
# 63     16
# 64     20
# 65      4
# 66      4
# 67    327
# 68    465
# 69   1742
# 70   2494
# 71  13952
# 72  18122
# 73     20
# 74     22
# 75      7
# 76     15
# 77     31
# 78     38
# 79     59
# 80     46
#
# [81 rows x 4 columns]

# %%
query = """
select 
    p.person_id, (v.visit_start_date - p.birth_datetime)/365.25 as age
from 
    person p
    
    left outer join
    
    visit_occurrence v
    
    on p.person_id = v.person_id
    
limit 10    
    ;"""
#query = "select datepart(yyyy, birth_datetime) from person limit 5;"
temp = pd.read_sql_query(query, conn)
temp
# Out:
#    person_id     age
# 0   62063589   0.000
# 1   62063590  76.522
# 2   62063591  47.841
# 3   62063592   0.000
# 4   62063593  65.938
# 5   62063594   0.000
# 6   62063595   0.000
# 7   62063596  41.787
# 8   62063597   0.000
# 9   62063598  50.143

# %% [markdown]
# ## Death table

# %%
pd.read_sql_query('select * from death limit 10;', conn)
# Out:
#    person_id  death_date      death_datetime  death_type_concept_id  \
# 0   62063368  2188-11-22 2188-11-22 12:00:00               38003569
# 1   62063384  2198-02-18 2198-02-18 03:55:00               38003569
# 2   62063393  2182-07-31 2182-07-31 06:45:00               38003569
# 3   62063403  2145-03-19 2145-03-19 07:00:00               38003569
# 4   62063425  2156-08-26 2156-08-26 12:00:00               38003569
# 5   62063429  2182-02-28 2182-02-28 14:50:00               38003569
# 6   62063436  2147-11-11 2147-11-11 22:57:00               38003569
# 7   62063437  2171-06-27 2171-06-27 17:10:00               38003569
# 8   62063444  2123-07-16 2123-07-16 23:19:00               38003569
# 9   62063447  2129-12-20 2129-12-20 01:37:00               38003569
#
#   cause_concept_id cause_source_value cause_source_concept_id
# 0             None               None                    None
# 1             None               None                    None
# 2             None               None                    None
# 3             None               None                    None
# 4             None               None                    None
# 5             None               None                    None
# 6             None               None                    None
# 7             None               None                    None
# 8             None               None                    None
# 9             None               None                    None

# %% [markdown]
# ## Visit_occurrence table

# %%
pd.read_sql_query('select * from visit_occurrence limit 10;', conn)
# Out:
#    visit_occurrence_id  person_id  visit_concept_id visit_start_date  \
# 0                  213   62063589              9201       2138-07-17
# 1                  214   62063590               262       2101-10-20
# 2                  215   62063591               262       2191-03-15
# 3                  216   62063592              9201       2103-02-02
# 4                  217   62063593              9201       2175-05-30
# 5                  218   62063594              9201       2121-05-23
# 6                  219   62063595              9201       2117-11-20
# 7                  220   62063596               262       2149-11-09
# 8                  221   62063597              9201       2103-06-28
# 9                  222   62063598               262       2178-04-15
#
#   visit_start_datetime visit_end_date  visit_end_datetime  \
# 0  2138-07-17 19:04:00     2138-07-21 2138-07-21 15:48:00
# 1  2101-10-20 17:09:00     2101-10-31 2101-10-31 13:58:00
# 2  2191-03-15 13:10:00     2191-03-23 2191-03-23 18:41:00
# 3  2103-02-02 04:31:00     2103-02-04 2103-02-04 12:15:00
# 4  2175-05-30 07:15:00     2175-06-15 2175-06-15 16:00:00
# 5  2121-05-23 15:05:00     2121-05-27 2121-05-27 11:57:00
# 6  2117-11-20 10:22:00     2117-11-24 2117-11-24 14:20:00
# 7  2149-11-09 11:13:00     2149-11-14 2149-11-14 10:15:00
# 8  2103-06-28 11:36:00     2103-07-06 2103-07-06 12:10:00
# 9  2178-04-15 20:46:00     2178-05-11 2178-05-11 19:00:00
#
#    visit_type_concept_id provider_id  care_site_id visit_source_value  \
# 0               44818518        None      67099830            NEWBORN
# 1               44818518        None      67099830          EMERGENCY
# 2               44818518        None      67099830          EMERGENCY
# 3               44818518        None      67099830            NEWBORN
# 4               44818518        None      67099830           ELECTIVE
# 5               44818518        None      67099830            NEWBORN
# 6               44818518        None      67099830            NEWBORN
# 7               44818518        None      67099830          EMERGENCY
# 8               44818518        None      67099830            NEWBORN
# 9               44818518        None      67099830          EMERGENCY
#
#    visit_source_concept_id  admitting_concept_id     admitting_source_value  \
# 0               2001033356                  8940  PHYS REFERRAL/NORMAL DELI
# 1               2001033355                  8870       EMERGENCY ROOM ADMIT
# 2               2001033355                  8870       EMERGENCY ROOM ADMIT
# 3               2001033356                  8940  PHYS REFERRAL/NORMAL DELI
# 4               2001033354                  8940  PHYS REFERRAL/NORMAL DELI
# 5               2001033356                  8940  PHYS REFERRAL/NORMAL DELI
# 6               2001033356                  8940  PHYS REFERRAL/NORMAL DELI
# 7               2001033355                  8870       EMERGENCY ROOM ADMIT
# 8               2001033356                  8940  PHYS REFERRAL/NORMAL DELI
# 9               2001033355                  8870       EMERGENCY ROOM ADMIT
#
#    admitting_source_concept_id  discharge_to_concept_id  \
# 0                   2001031830                     8536
# 1                   2001031826                     8863
# 2                   2001031826                     8536
# 3                   2001031830                     8536
# 4                   2001031830                     8536
# 5                   2001031830                     8536
# 6                   2001031830                     8536
# 7                   2001031826                  4216643
# 8                   2001031830                     8863
# 9                   2001031826                     8536
#
#    discharge_to_source_value  discharge_to_source_concept_id  \
# 0                       HOME                      2001036536
# 1                        SNF                      2001036544
# 2  HOME WITH HOME IV PROVIDR                      2001036538
# 3                       HOME                      2001036536
# 4           HOME HEALTH CARE                      2001036537
# 5                       HOME                      2001036536
# 6                       HOME                      2001036536
# 7               DEAD/EXPIRED                      2001036535
# 8        SHORT TERM HOSPITAL                      2001036543
# 9           HOME HEALTH CARE                      2001036537
#
#   preceding_visit_occurrence_id
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
# 5                          None
# 6                          None
# 7                          None
# 8                          None
# 9                          None

# %% [markdown]
# ## Measurement table

# %%
query = """
select
    *
from
    measurement
limit
    10;"""

pd.read_sql_query(query, conn)
# Out:
#    measurement_id  person_id  measurement_concept_id  \
# 0        27861030   62105861                 3023314
# 1        27851085   62105861                 3000330
# 2        27860999   62105861                 3003282
# 3        27851103   62105861                 3014576
# 4        27831861   62105861                 3005897
# 5        27861037   62105861                 3020416
# 6        27822002   62105861                 3024629
# 7        27812669   62105861                 3024128
# 8        27831860   62105861                 3022621
# 9        27861005   62105861                 3000330
#
#                             measurement_concept_name measurement_concept_code  \
# 0  Hematocrit [Volume Fraction] of Blood by Autom...                   4544-3
# 1            Specific gravity of Urine by Test strip                   5811-5
# 2     Leukocytes [#/volume] in Blood by Manual count                    804-5
# 3                              Chloride serum/plasma                   2075-0
# 4       Protein [Mass/volume] in Urine by Test strip                   5804-0
# 5  Erythrocytes [#/volume] in Blood by Automated ...                    789-8
# 6                             Glucose urine dipstick                   5792-7
# 7                       Total Bilirubin serum/plasma                   1975-2
# 8                          pH of Urine by Test strip                   5803-2
# 9            Specific gravity of Urine by Test strip                   5811-5
#
#   measurement_concept_code_system measurement_date measurement_datetime  \
# 0                           LOINC       2117-09-15  2117-09-15 10:20:00
# 1                           LOINC       2117-09-13  2117-09-13 08:21:00
# 2                           LOINC       2117-09-14  2117-09-14 01:21:00
# 3                           LOINC       2117-09-14  2117-09-14 01:21:00
# 4                           LOINC       2117-09-12  2117-09-12 08:41:00
# 5                           LOINC       2117-09-15  2117-09-15 10:20:00
# 6                           LOINC       2117-09-11  2117-09-11 08:53:00
# 7                           LOINC       2117-09-11  2117-09-11 08:22:00
# 8                           LOINC       2117-09-12  2117-09-12 08:41:00
# 9                           LOINC       2117-09-14  2117-09-14 10:08:00
#
#    measurement_type_concept_id measurement_type_concept_name  \
# 0                   2000000009                 Labs - Hemato
# 1                   2000000009                 Labs - Hemato
# 2                   2000000009                 Labs - Hemato
# 3                   2000000011              Labs - Chemistry
# 4                   2000000009                 Labs - Hemato
# 5                   2000000009                 Labs - Hemato
# 6                   2000000009                 Labs - Hemato
# 7                   2000000011              Labs - Chemistry
# 8                   2000000009                 Labs - Hemato
# 9                   2000000009                 Labs - Hemato
#
#          ...          unit_concept_code_system range_low  range_high  \
# 0        ...                              UCUM      None        None
# 1        ...                              None      None        None
# 2        ...                              UCUM      None        None
# 3        ...                              UCUM      None        None
# 4        ...                              UCUM      None        None
# 5        ...                              UCUM      None        None
# 6        ...                              UCUM      None        None
# 7        ...                              UCUM      None        None
# 8        ...                              UCUM      None        None
# 9        ...                              None      None        None
#
#    provider_id  visit_occurrence_id visit_detail_id measurement_source_value  \
# 0         None                47371            None                    51221
# 1         None                47371            None                    51498
# 2         None                47371            None                    51301
# 3         None                47371            None                    50902
# 4         None                47371            None                    51492
# 5         None                47371            None                    51279
# 6         None                47371            None                    51478
# 7         None                47371            None                    50885
# 8         None                47371            None                    51491
# 9         None                47371            None                    51498
#
#   measurement_source_concept_id unit_source_value value_source_value
# 0                    2001031483                 %               32.2
# 1                    2001031633              None              1.006
# 2                    2001031563              K/uL               10.5
# 3                    2001031166             mEq/L                103
# 4                    2001031627             mg/dL                100
# 5                    2001031541              m/uL               3.86
# 6                    2001031613             mg/dL                300
# 7                    2001031149             mg/dL                0.5
# 8                    2001031626             units                6.5
# 9                    2001031633              None              1.006
#
# [10 rows x 27 columns]

# %%
query = """
select
    m.person_id, m.measurement_datetime, m.measurement_id, m.value_source_value as value, m.unit_source_value as unit, 
    c.concept_name as measurement_type, c1.concept_name as measurement_source
from
    measurement m
    left outer join 
    (select concept_id, concept_name from concept) c
    on m.measurement_type_concept_id = c.concept_id
    left outer join 
    (select concept_id, concept_name from concept) c1
    on m.measurement_source_concept_id = c1.concept_id
where 
    unit_source_value = '%mmHg%'
order by
    person_id, measurement_datetime
limit
    10;"""
bpm = pd.read_sql_query(query, conn)
bpm
# Out:
# Empty DataFrame
# Columns: [person_id, measurement_datetime, measurement_id, value, unit, measurement_type, measurement_source]
# Index: []

# %% [markdown]
# ## Procedure_occurrence

# %%
pd.read_sql_query('select * from procedure_occurrence limit 10;', conn)
# Out:
#    procedure_occurrence_id  person_id  procedure_concept_id procedure_date  \
# 0                   509041   62105861               4033552     2117-09-11
# 1                   509039   62105861               4033552     2117-09-11
# 2                   509038   62105861               4033552     2117-09-11
# 3                   509037   62105861               4203130     2117-09-11
# 4                   509043   62105861               4313303     2117-09-11
# 5                   509036   62105861               4027135     2117-09-11
# 6                   509042   62105861               4313303     2117-09-11
# 7                   509040   62105861               4033552     2117-09-11
# 8                   342915   62095228               4040551     2150-04-17
# 9                   342913   62095228               4033552     2150-04-17
#
#    procedure_datetime  procedure_type_concept_id modifier_concept_id quantity  \
# 0 2117-09-11 11:46:00                        257                None     None
# 1 2117-09-11 11:46:00                        257                None     None
# 2 2117-09-11 11:46:00                        257                None     None
# 3 2117-09-11 11:46:00                        257                None     None
# 4 2117-09-11 11:46:00                        257                None     None
# 5 2117-09-11 11:46:00                        257                None     None
# 6 2117-09-11 11:46:00                        257                None     None
# 7 2117-09-11 11:46:00                        257                None     None
# 8 2150-04-17 15:34:00                        257                None     None
# 9 2150-04-17 15:34:00                        257                None     None
#
#   provider_id  visit_occurrence_id visit_detail_id  \
# 0        None                47371            None
# 1        None                47371            None
# 2        None                47371            None
# 3        None                47371            None
# 4        None                47371            None
# 5        None                47371            None
# 6        None                47371            None
# 7        None                47371            None
# 8        None                47029            None
# 9        None                47029            None
#
#         procedure_source_value  procedure_source_concept_id  \
# 0       Critical care services                      2514441
# 1       Critical care services                      2514441
# 2       Critical care services                      2514441
# 3  Hospital inpatient services                      2514414
# 4  Hospital inpatient services                      2514409
# 5  Hospital inpatient services                      2514408
# 6  Hospital inpatient services                      2514409
# 7       Critical care services                      2514441
# 8        Diagnostic ultrasound                      2211779
# 9       Critical care services                      2514441
#
#   qualifier_source_value
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# 5                   None
# 6                   None
# 7                   None
# 8                   None
# 9                   None

# %% [markdown]
# ## Condition_occurrence table

# %%
pd.read_sql_query('select * from condition_occurrence limit 10;', conn)
# Out:
#    condition_occurrence_id  person_id  condition_concept_id  \
# 0                  5622381   62105861                443597
# 1                  5622371   62105861                439770
# 2                  5622382   62105861                373999
# 3                  5622374   62105861                 26727
# 4                  5622373   62105861                197320
# 5                  5622379   62105861                200687
# 6                  5622377   62105861                195847
# 7                  5622383   62105861                376683
# 8                  5622386   62105861                     0
# 9                  5622385   62105861                134441
#
#   condition_start_date condition_start_datetime condition_end_date  \
# 0           2117-09-11      2117-09-11 08:59:00         2117-09-17
# 1           2117-09-11      2117-09-11 08:59:00         2117-09-17
# 2           2117-09-11      2117-09-11 08:59:00         2117-09-17
# 3           2117-09-11      2117-09-11 08:59:00         2117-09-17
# 4           2117-09-11      2117-09-11 08:59:00         2117-09-17
# 5           2117-09-11      2117-09-11 08:59:00         2117-09-17
# 6           2117-09-11      2117-09-11 08:59:00         2117-09-17
# 7           2117-09-11      2117-09-11 08:59:00         2117-09-17
# 8           2117-09-11      2117-09-11 08:59:00         2117-09-17
# 9           2117-09-11      2117-09-11 08:59:00         2117-09-17
#
#   condition_end_datetime  condition_type_concept_id stop_reason provider_id  \
# 0    2117-09-17 16:45:00                   38000194        None        None
# 1    2117-09-17 16:45:00                   38000184        None        None
# 2    2117-09-17 16:45:00                   38000195        None        None
# 3    2117-09-17 16:45:00                   38000187        None        None
# 4    2117-09-17 16:45:00                   38000186        None        None
# 5    2117-09-17 16:45:00                   38000192        None        None
# 6    2117-09-17 16:45:00                   38000190        None        None
# 7    2117-09-17 16:45:00                   38000196        None        None
# 8    2117-09-17 16:45:00                   44818709        None        None
# 9    2117-09-17 16:45:00                   38000198        None        None
#
#    visit_occurrence_id visit_detail_id condition_source_value  \
# 0                47371            None                   5853
# 1                47371            None                  25013
# 2                47371            None                  25053
# 3                47371            None                   5780
# 4                47371            None                   5849
# 5                47371            None                  25043
# 6                47371            None                   5363
# 7                47371            None                  36201
# 8                47371            None                  V1351
# 9                47371            None                   7078
#
#    condition_source_concept_id condition_status_source_value  \
# 0                     44827888                          None
# 1                     44822934                          None
# 2                     44820684                          None
# 3                     44819811                          None
# 4                     44826731                          None
# 5                     44834549                          None
# 6                     44822024                          None
# 7                     44831148                          None
# 8                     44824960                          None
# 9                     44831472                          None
#
#   condition_status_concept_id
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None

# %% [markdown]
# ## Observation table

# %%
pd.read_sql_query('select * from observation limit 10;', conn)
# Out:
#    observation_id  person_id  observation_concept_id observation_date  \
# 0         3519795   62105861                 4085802       2117-09-11
# 1         3519818   62105861                 4085802       2117-09-14
# 2         3519817   62105861                 4085802       2117-09-13
# 3         3519816   62105861                 4085802       2117-09-14
# 4         3519790   62105861                 4085802       2117-09-11
# 5         3519809   62105861                 4085802       2117-09-13
# 6         3519799   62105861                 4085802       2117-09-11
# 7         3519801   62105861                 4085802       2117-09-13
# 8         3519812   62105861                 4085802       2117-09-14
# 9         3519807   62105861                 4085802       2117-09-11
#
#   observation_datetime  observation_type_concept_id value_as_number  \
# 0  2117-09-11 00:00:00                     38000280            None
# 1  2117-09-14 00:00:00                     38000280            None
# 2  2117-09-13 04:00:00                     38000280            None
# 3  2117-09-14 00:00:00                     38000280            None
# 4  2117-09-11 00:00:00                     38000280            None
# 5  2117-09-13 00:00:00                     38000280            None
# 6  2117-09-11 00:00:00                     38000280            None
# 7  2117-09-13 01:40:00                     38000280            None
# 8  2117-09-14 00:00:00                     38000280            None
# 9  2117-09-11 00:00:00                     38000280            None
#
#                        value_as_string value_as_concept_id  \
# 0              20 Gauge Insertion Date                None
# 1              22 Gauge Insertion Date                None
# 2  Impaired Skin  - Dressing Change #1                None
# 3              22 Gauge Insertion Date                None
# 4              20 Gauge Insertion Date                None
# 5              22 Gauge Insertion Date                None
# 6              20 Gauge Insertion Date                None
# 7              22 Gauge Insertion Date                None
# 8              20 Gauge Insertion Date                None
# 9              20 Gauge Insertion Date                None
#
#   qualifier_concept_id unit_concept_id  provider_id  visit_occurrence_id  \
# 0                 None            None        98703                47371
# 1                 None            None        98703                47371
# 2                 None            None        98703                47371
# 3                 None            None        98703                47371
# 4                 None            None        96516                47371
# 5                 None            None        98703                47371
# 6                 None            None        98703                47371
# 7                 None            None        98703                47371
# 8                 None            None       100652                47371
# 9                 None            None        95926                47371
#
#    visit_detail_id observation_source_value observation_source_concept_id  \
# 0         67158807                     None                          None
# 1         67031333                     None                          None
# 2         67031333                     None                          None
# 3         67031333                     None                          None
# 4         67158807                     None                          None
# 5         67031333                     None                          None
# 6         67158807                     None                          None
# 7         67031333                     None                          None
# 8         67031333                     None                          None
# 9         67158807                     None                          None
#
#   unit_source_value qualifier_source_value
# 0              None                   None
# 1              None                   None
# 2              None                   None
# 3              None                   None
# 4              None                   None
# 5              None                   None
# 6              None                   None
# 7              None                   None
# 8              None                   None
# 9              None                   None

# %% [markdown]
# ## Drug_exposure table

# %%
pd.read_sql_query('select * from drug_exposure limit 10;', conn)
# Out:
#    drug_exposure_id  person_id  drug_concept_id drug_exposure_start_date  \
# 0          65134749   62105861         40168991               2117-09-12
# 1          65133109   62105861                0               2117-09-14
# 2          65133110   62105861         19079524               2117-09-14
# 3          65136366   62105861         19078557               2117-09-11
# 4          65134747   62105861                0               2117-09-12
# 5          65136379   62105861         40232756               2117-09-11
# 6          65134755   62105861                0               2117-09-12
# 7          65134753   62105861                0               2117-09-12
# 8          65134751   62105861                0               2117-09-12
# 9          65134750   62105861                0               2117-09-12
#
#   drug_exposure_start_datetime drug_exposure_end_date  \
# 0                   2117-09-12             2117-09-14
# 1                   2117-09-14             2117-09-15
# 2                   2117-09-14             2117-09-15
# 3                   2117-09-11             2117-09-11
# 4                   2117-09-12             2117-09-13
# 5                   2117-09-11             2117-09-17
# 6                   2117-09-12             2117-09-15
# 7                   2117-09-12             2117-09-15
# 8                   2117-09-12             2117-09-15
# 9                   2117-09-12             2117-09-14
#
#   drug_exposure_end_datetime verbatim_end_date  drug_type_concept_id  \
# 0                 2117-09-14              None              38000177
# 1                 2117-09-15              None              38000177
# 2                 2117-09-15              None              38000177
# 3                 2117-09-11              None              38000177
# 4                 2117-09-13              None              38000177
# 5                 2117-09-17              None              38000177
# 6                 2117-09-15              None              38000177
# 7                 2117-09-15              None              38000177
# 8                 2117-09-15              None              38000177
# 9                 2117-09-14              None              38000177
#
#   stop_reason          ...          route_concept_id  lot_number provider_id  \
# 0        None          ...                   4112421        None        None
# 1        None          ...                   4112421        None        None
# 2        None          ...                   4112421        None        None
# 3        None          ...                   4112421        None        None
# 4        None          ...                   4112421        None        None
# 5        None          ...                   4128794        None        None
# 6        None          ...                   4112421        None        None
# 7        None          ...                   4112421        None        None
# 8        None          ...                   4112421        None        None
# 9        None          ...                   4112421        None        None
#
#   visit_occurrence_id  visit_detail_id drug_source_value  \
# 0               47371             None       00008092355
# 1               47371             None       00338067104
# 2               47371             None       00338004903
# 3               47371             None       00002821501
# 4               47371             None       00338008504
# 5               47371             None       00406055262
# 6               47371             None                 0
# 7               47371             None                 0
# 8               47371             None                 0
# 9               47371             None                 0
#
#   drug_source_concept_id  route_source_value dose_unit_source_value  \
# 0                   None                  IV                   VIAL
# 1                   None                  IV                    BAG
# 2                   None                  IV                     mL
# 3                   None             IV DRIP                     mL
# 4                   None                  IV                     mL
# 5                   None               PO/NG                    TAB
# 6                   None                  IV                    BAG
# 7                   None                  IV                    BAG
# 8                   None                  IV                    BAG
# 9                   None                  IV                   VIAL
#
#   quantity_source_value
# 0                     1
# 1                     1
# 2                   500
# 3                     1
# 4                  1000
# 5                     1
# 6                     1
# 7                     1
# 8                     1
# 9                     1
#
# [10 rows x 24 columns]

# %%
pd.read_sql_query('select * from note limit 10;', conn)
# Out:
#     note_id  person_id   note_date       note_datetime  note_type_concept_id  \
# 0  55679581   62105861  2117-09-17                 NaT              44814637
# 1  56833725   62105861  2117-09-11 2117-09-11 11:12:00              44814641
# 2  56200264   62095228  2150-04-19 2150-04-19 06:28:00                     0
# 3  56200473   62095228  2150-04-18 2150-04-18 05:30:00              44814644
# 4  56198294   62095228  2150-04-19 2150-04-19 02:35:00              44814644
# 5  56200709   62095228  2150-04-18 2150-04-18 02:47:00                     0
# 6  55650161   62095228  2150-04-21                 NaT              44814637
# 7  56200262   62095228  2150-04-19 2150-04-19 06:28:00                     0
# 8  55815916   62095228  2150-04-17                 NaT              44814642
# 9  56198312   62095228  2150-04-18 2150-04-18 02:47:00                     0
#
#    note_class_concept_id                         note_title  \
# 0                      0                             Report
# 1                      0                   CHEST (PA & LAT)
# 2                      0   Physician Resident Progress Note
# 3                      0              Nursing Progress Note
# 4                      0              Nursing Progress Note
# 5                      0  Physician Resident Admission Note
# 6                      0                             Report
# 7                      0   Physician Resident Progress Note
# 8                      0                             Report
# 9                      0  Physician Resident Admission Note
#
#                                            note_text  encoding_concept_id  \
# 0  Admission Date:  [**2117-9-11**]              ...                    0
# 1  [**2117-9-11**] 11:12 AM\n CHEST (PA & LAT)   ...                    0
# 2  Chief Complaint:\n   24 Hour Events:\n CALLED ...                    0
# 3  59 year old male with HCV-related cirrhosis, g...                    0
# 4  59 year old male with HCV-related cirrhosis, g...                    0
# 5  Chief Complaint:  coffee ground emesis, light ...                    0
# 6  Admission Date:  [**2150-4-17**]              ...                    0
# 7  Chief Complaint:\n   24 Hour Events:\n CALLED ...                    0
# 8  Sinus rhythm\nProlonged QT interval is nonspec...                    0
# 9  Chief Complaint:  coffee ground emesis, light ...                    0
#
#    language_concept_id  provider_id  visit_occurrence_id  note_source_value  \
# 0             40639385          NaN                47371  Discharge summary
# 1             40639385          NaN                47371          Radiology
# 2             40639385      97707.0                47029         Physician
# 3             40639385      94923.0                47029            Nursing
# 4             40639385      94923.0                47029            Nursing
# 5             40639385      95486.0                47029         Physician
# 6             40639385          NaN                47029  Discharge summary
# 7             40639385      97707.0                47029         Physician
# 8             40639385          NaN                47029                ECG
# 9             40639385     100299.0                47029         Physician
#
#   visit_detail_id
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None

# %% [markdown]
# ## Note_nlp table

# %%
pd.read_sql_query('select * from note_nlp limit 10;', conn)
# Out:
#    note_nlp_id   note_id  section_concept_id snippet  \
# 0    118083470  55680405                   0    None
# 1    118083471  55680405                   0    None
# 2    118083472  55680405                   0    None
# 3    118083473  55680405                   0    None
# 4    118083474  55680405                   0    None
# 5    118083475  55680405          2005203326    None
# 6    118083476  55680405          2005203328    None
# 7    118083477  55680405                   0    None
# 8    118083478  55680405                   0    None
# 9    118083479  55680405          2005203559    None
#
#                                      lexical_variant  note_nlp_concept_id  \
# 0  Discharge Medications:\n1. aspirin 325 mg Tabl...              4307844
# 1                   Discharge Disposition:\nHome\n\n              4307844
# 2  Discharge Diagnosis:\nAbdominal Aortic Aneurys...              4307844
# 3                             Discharge Condition:\n              4307844
# 4               Mental Status: Clear and coherent.\n              4307844
# 5   Level of Consciousness: Alert and interactive.\n              4307844
# 6   Activity Status: Ambulatory - Independent.\n\n\n              4307844
# 7  Discharge Instructions:\nYou were admitted to ...              4307844
# 8  Medications:\n??????\tTake Aspirin 325mg (ente...              4307844
# 9  What activities you can and cannot do:\n??????...              4307844
#
#    note_nlp_source_concept_id                   nlp_system    nlp_date  \
# 0                           0  UIMA Section Extractor v1.0  2018-04-14
# 1                           0  UIMA Section Extractor v1.0  2018-04-14
# 2                           0  UIMA Section Extractor v1.0  2018-04-14
# 3                           0  UIMA Section Extractor v1.0  2018-04-14
# 4                           0  UIMA Section Extractor v1.0  2018-04-14
# 5                           0  UIMA Section Extractor v1.0  2018-04-14
# 6                           0  UIMA Section Extractor v1.0  2018-04-14
# 7                           0  UIMA Section Extractor v1.0  2018-04-14
# 8                           0  UIMA Section Extractor v1.0  2018-04-14
# 9                           0  UIMA Section Extractor v1.0  2018-04-14
#
#              nlp_datetime term_exists term_temporal term_modifiers  \
# 0 2018-04-14 23:36:50.552        None          None           None
# 1 2018-04-14 23:36:50.552        None          None           None
# 2 2018-04-14 23:36:50.552        None          None           None
# 3 2018-04-14 23:36:50.552        None          None           None
# 4 2018-04-14 23:36:50.552        None          None           None
# 5 2018-04-14 23:36:50.552        None          None           None
# 6 2018-04-14 23:36:50.552        None          None           None
# 7 2018-04-14 23:36:50.552        None          None           None
# 8 2018-04-14 23:36:50.552        None          None           None
# 9 2018-04-14 23:36:50.552        None          None           None
#
#    offset_begin  offset_end                    section_source_value  \
# 0          2936        3584                  Discharge Medications:
# 1          3584        3613                  Discharge Disposition:
# 2          3613        3678                    Discharge Diagnosis:
# 3          3678        3699                    Discharge Condition:
# 4          3699        3734                          Mental Status:
# 5          3734        3781                 Level of Consciousness:
# 6          3781        3826                        Activity Status:
# 7          3826        4195                 Discharge Instructions:
# 8          4195        5283                            Medications:
# 9          5283        5981  What activities you can and cannot do:
#
#    section_source_concept_id
# 0                 2001042498
# 1                 2001042483
# 2                 2001042489
# 3                 2001042490
# 4                 2001042516
# 5                 2001042517
# 6                 2001042519
# 7                 2001042495
# 8                 2001042670
# 9                 2001042750

# %% [markdown]
# ## Cohort_definition table

# %%
pd.read_sql_query('select * from cohort_definition limit 10;', conn)
# Out:
#    cohort_definition_id cohort_definition_name cohort_definition_description  \
# 0                     0   No particular cohort                          None
# 1                     1           angus severe            jerome description
# 2                     2            angus shock            jerome description
# 3                     3            accp severe            jerome description
# 4                     4             accp shock            jerome description
# 5                     5         sepsis3 severe            jerome description
# 6                     6          sepsis3 shock            jerome description
#
#    definition_type_concept_id cohort_definition_syntax  subject_concept_id  \
# 0                           0                     None                   0
# 1                           0                     None                   8
# 2                           0                     None                   8
# 3                           0                     None                   8
# 4                           0                     None                   8
# 5                           0                     None                   8
# 6                           0                     None                   8
#
#   cohort_initiation_date
# 0             2018-04-14
# 1             2018-04-14
# 2             2018-04-14
# 3             2018-04-14
# 4             2018-04-14
# 5             2018-04-14
# 6             2018-04-14

# %% [markdown]
# ## Cohort_attribute table

# %%
pd.read_sql_query('select * from cohort_attribute limit 10;', conn)
# Out:
#    cohort_definition_id cohort_start_date cohort_end_date  subject_id  \
# 0                     0        2117-09-11      2117-09-11    67158807
# 1                     0        2117-09-11      2117-09-15    67031333
# 2                     0        2117-09-15      2117-09-17    67031335
# 3                     0        2150-04-17      2150-04-17    67158811
# 4                     0        2150-04-17      2150-04-17    67040892
# 5                     0        2150-04-17      2150-04-17    67040893
# 6                     0        2150-04-17      2150-04-19    67040894
# 7                     0        2150-04-19      2150-04-21    67040895
# 8                     0        2108-04-06      2108-04-06    67158816
# 9                     0        2108-04-06      2108-04-11    66892538
#
#    attribute_definition_id  value_as_number  value_as_concept_id
# 0                        2         0.117072                    0
# 1                        2         4.256701                    0
# 2                        2         1.950764                    0
# 3                        2         0.101181                    0
# 4                        2         0.010822                    0
# 5                        2         0.000567                    0
# 6                        2         1.931088                    0
# 7                        2         2.141435                    0
# 8                        2         0.174479                    0
# 9                        2         4.977639                    0

# %% [markdown]
# ## Attribute_definition table

# %%
pd.read_sql_query('select * from attribute_definition limit 10;', conn)
# Out:
#    attribute_definition_id          attribute_name  \
# 0                        1           Callout Delay
# 1                        2      Visit Detail Delay
# 2                        3  Visit Occurrence Delay
# 3                        4          duration_hours
# 4                        5                    sofa
# 5                        6             respiration
# 6                        7             coagulation
# 7                        8                   liver
# 8                        9          cardiovascular
# 9                       10                     cns
#
#             attribute_description  attribute_type_concept_id attribute_syntax
# 0                            None                          0             None
# 1                            None                          0             None
# 2                            None                          0             None
# 3  ventdurations - duration_hours                          0             None
# 4                     sofa - sofa                          0             None
# 5              sofa - respiration                          0             None
# 6              sofa - coagulation                          0             None
# 7                    sofa - liver                          0             None
# 8           sofa - cardiovascular                          0             None
# 9                      sofa - cns                          0             None

# %% [markdown]
# ## Care_site table

# %%
pd.read_sql_query('select * from care_site limit 10;', conn)
# Out:
#    care_site_id care_site_name  place_of_service_concept_id location_id  \
# 0      67099738    CCU ward #7                      4149943        None
# 1      67099739   CCU ward #37                      4149943        None
# 2      67099740   CCU ward #57                      4149943        None
# 3      67099741  CSRU ward #33                      4138949        None
# 4      67099742  CSRU ward #12                      4138949        None
# 5      67099743  CSRU ward #14                      4138949        None
# 6      67099744  CSRU ward #23                      4138949        None
# 7      67099745  CSRU ward #15                      4138949        None
# 8      67099746  CSRU ward #47                      4138949        None
# 9      67099747  MICU ward #52                     40481392        None
#
#   care_site_source_value  place_of_service_source_value
# 0                    CCU             Coronary care unit
# 1                    CCU             Coronary care unit
# 2                    CCU             Coronary care unit
# 3                   CSRU  Cardiac surgery recovery unit
# 4                   CSRU  Cardiac surgery recovery unit
# 5                   CSRU  Cardiac surgery recovery unit
# 6                   CSRU  Cardiac surgery recovery unit
# 7                   CSRU  Cardiac surgery recovery unit
# 8                   CSRU  Cardiac surgery recovery unit
# 9                   MICU    Medical intensive care unit

# %% [markdown]
# ## Concept table

# %%
pd.read_sql_query('select * from concept limit 10;', conn)
# Out:
#    concept_id                                       concept_name  domain_id  \
# 0     2103359                           Excision of rib, partial  Procedure
# 1     2103847                              Excision, radial head  Procedure
# 2     2104737  Tenotomy, adductor of hip, percutaneous (separ...  Procedure
# 3     2105444                           Arthrodesis, ankle, open  Procedure
# 4     2105876                          Strapping; hand or finger  Procedure
# 5     2106077  Arthroscopy, subtalar joint, surgical; with de...  Procedure
# 6     2106527                 Laryngoscopy, flexible; diagnostic  Procedure
# 7    42740408                                       Speculoscopy  Procedure
# 8    42740457                             Starch granules, feces  Procedure
# 9     2108119             Transfusion, blood or blood components  Procedure
#
#   vocabulary_id concept_class_id standard_concept concept_code  \
# 0          CPT4             CPT4                S        21600
# 1          CPT4             CPT4                S        24130
# 2          CPT4             CPT4                S        27000
# 3          CPT4             CPT4                S        27870
# 4          CPT4             CPT4                S        29280
# 5          CPT4             CPT4                S        29906
# 6          CPT4             CPT4                S        31575
# 7          CPT4             CPT4             None        0031T
# 8          CPT4             CPT4             None        89225
# 9          CPT4             CPT4                S        36430
#
#   valid_start_date valid_end_date invalid_reason
# 0       1970-01-01     2099-12-31           None
# 1       1970-01-01     2099-12-31           None
# 2       1970-01-01     2099-12-31           None
# 3       1970-01-01     2099-12-31           None
# 4       1970-01-01     2099-12-31           None
# 5       2008-04-01     2099-12-31           None
# 6       1970-01-01     2099-12-31           None
# 7       2003-03-31     2009-04-06              D
# 8       2004-03-31     2011-05-05              D
# 9       1970-01-01     2099-12-31           None

# %%
query = """
select 
    *
from
    concept
where
    concept_name LIKE '%Chloride%'
and 
    domain_id = 'Measurement'
    ;"""

search = pd.read_sql_query(query, conn)
search
# Out:
#      concept_id                                       concept_name  \
# 0    2001019318  label:[ABG Chloride]dbsource:[carevue]linksto:...
# 1    2001019976  label:[Chloride (100-112)]dbsource:[carevue]li...
# 2    2001020851  label:[Calcium Chloride]dbsource:[carevue]link...
# 3    2001021134  label:[Chloride  (100-112)]dbsource:[carevue]l...
# 4    2001021240  label:[Chloride]dbsource:[carevue]linksto:[cha...
# 5    2001022289  label:[Potassium Chloride]dbsource:[carevue]li...
# 6    2001022320  label:[Sodium Chloride]dbsource:[carevue]links...
# 7    2001024119  label:[Sodium Chloride]dbsource:[carevue]links...
# 8    2001024120  label:[Potassium Chloride]dbsource:[carevue]li...
# 9    2001024123  label:[Calcium Chloride 10%]dbsource:[carevue]...
# 10   2001024229  label:[Calcium Chloride]dbsource:[carevue]link...
# 11   2001027125  label:[Potassium Chloride]dbsource:[metavision...
# 12   2001028179  label:[Chloride (serum) (soft)]dbsource:[metav...
# 13   2001028180  label:[Chloride (whole blood) (soft)]dbsource:...
# 14   2001029930  label:[Chloride (serum)]dbsource:[metavision]l...
# 15   2001030340  label:[Chloride (whole blood)]dbsource:[metavi...
# 16   2001031069  label:[Chloride, Whole Blood]fluid:[Blood]loin...
# 17   2001031102  label:[Chloride, Ascites]fluid:[Ascites]loinc:...
# 18   2001031166        label:[Chloride]fluid:[Blood]loinc:[2075-0]
# 19   2001031277  label:[Chloride, CSF]fluid:[Cerebrospinal Flui...
# 20   2001031294  label:[Chloride, Body Fluid]fluid:[Other Body ...
# 21   2001031314  label:[Chloride, Pleural]fluid:[Pleural]loinc:...
# 22   2001031326  label:[Chloride, Stool]fluid:[Stool]loinc:[151...
# 23   2001031342  label:[Chloride, Urine]fluid:[Urine]loinc:[207...
# 24     44806562                        Chloride output measurement
# 25     45887972                                           Chloride
# 26      2212089  Basic metabolic panel (Calcium, ionized) This ...
# 27      2212090  Basic metabolic panel (Calcium, total) This pa...
# 28      2212093  Comprehensive metabolic panel This panel must ...
# 29      2212092  Electrolyte panel This panel must include the ...
# ..          ...                                                ...
# 88     40796899                         Chloride | Red Blood Cells
# 89     40797329                        Chloride | Peritoneal fluid
# 90     40773309                          Chloride | Vitreous fluid
# 91     40776710                                   Chloride | Urine
# 92     40774111                                     Chloride | XXX
# 93     40791705                           Chloride | Pleural fluid
# 94     40797427                               Vinyl Chloride | Air
# 95     40779954                  Methylene Chloride | Bld-Ser-Plas
# 96     40786714                             Vinyl Chloride | Urine
# 97     40773737                   Chloride | Cerebral spinal fluid
# 98     40773733                          Chloride | Amniotic Fluid
# 99     40781062                          Chloride | Blood arterial
# 100    40780989                           Methylene Chloride | Air
# 101    40793137                                   Chloride | Water
# 102    40785869                                           Chloride
# 103    40795337                           Chloride | Mother's milk
# 104    40787101                                  Chloride | Saliva
# 105    40787586                         Methylene Chloride | Water
# 106    40783494                                   Chloride | Stool
# 107    40794133                             Vinyl Chloride | Water
# 108    40792024                           Chloride | Gastric fluid
# 109    40790331                          Chloride | Dialysis fluid
# 110    40777672                            Chloride | Blood venous
# 111    40777610               Chloride | Dialysis fluid peritoneal
# 112    40788396                Chloride | Total parental nutrition
# 113    40793591                              Chloride | Body Fluid
# 114    40793588                            Chloride | Bld-Ser-Plas
# 115    46235783  Chloride [Moles/volume] in Serum, Plasma or Blood
# 116    21494529                  Chloride intake 24 hour Estimated
# 117    21494238                   Chloride intake 24 hour Measured
#
#        domain_id     vocabulary_id      concept_class_id standard_concept  \
# 0    Measurement     MIMIC d_items                 ABG's             None
# 1    Measurement     MIMIC d_items             Chemistry             None
# 2    Measurement     MIMIC d_items                  None             None
# 3    Measurement     MIMIC d_items             Chemistry             None
# 4    Measurement     MIMIC d_items             Chemistry             None
# 5    Measurement     MIMIC d_items                  None             None
# 6    Measurement     MIMIC d_items                  None             None
# 7    Measurement     MIMIC d_items                  None             None
# 8    Measurement     MIMIC d_items                  None             None
# 9    Measurement     MIMIC d_items                  None             None
# 10   Measurement     MIMIC d_items                  None             None
# 11   Measurement     MIMIC d_items           Medications             None
# 12   Measurement     MIMIC d_items                  Labs             None
# 13   Measurement     MIMIC d_items                  Labs             None
# 14   Measurement     MIMIC d_items                  Labs             None
# 15   Measurement     MIMIC d_items                  Labs             None
# 16   Measurement  MIMIC d_labitems             Blood Gas             None
# 17   Measurement  MIMIC d_labitems             Chemistry             None
# 18   Measurement  MIMIC d_labitems             Chemistry             None
# 19   Measurement  MIMIC d_labitems             Chemistry             None
# 20   Measurement  MIMIC d_labitems             Chemistry             None
# 21   Measurement  MIMIC d_labitems             Chemistry             None
# 22   Measurement  MIMIC d_labitems             Chemistry             None
# 23   Measurement  MIMIC d_labitems             Chemistry             None
# 24   Measurement            SNOMED             Procedure                S
# 25   Measurement              CPT4        CPT4 Hierarchy                C
# 26   Measurement              CPT4                  CPT4                S
# 27   Measurement              CPT4                  CPT4                S
# 28   Measurement              CPT4                  CPT4                S
# 29   Measurement              CPT4                  CPT4                S
# ..           ...               ...                   ...              ...
# 88   Measurement             LOINC       LOINC Hierarchy                C
# 89   Measurement             LOINC       LOINC Hierarchy                C
# 90   Measurement             LOINC       LOINC Hierarchy                C
# 91   Measurement             LOINC       LOINC Hierarchy                C
# 92   Measurement             LOINC       LOINC Hierarchy                C
# 93   Measurement             LOINC       LOINC Hierarchy                C
# 94   Measurement             LOINC       LOINC Hierarchy                C
# 95   Measurement             LOINC       LOINC Hierarchy                C
# 96   Measurement             LOINC       LOINC Hierarchy                C
# 97   Measurement             LOINC       LOINC Hierarchy                C
# 98   Measurement             LOINC       LOINC Hierarchy                C
# 99   Measurement             LOINC       LOINC Hierarchy                C
# 100  Measurement             LOINC       LOINC Hierarchy                C
# 101  Measurement             LOINC       LOINC Hierarchy                C
# 102  Measurement             LOINC       LOINC Hierarchy                C
# 103  Measurement             LOINC       LOINC Hierarchy                C
# 104  Measurement             LOINC       LOINC Hierarchy                C
# 105  Measurement             LOINC       LOINC Hierarchy                C
# 106  Measurement             LOINC       LOINC Hierarchy                C
# 107  Measurement             LOINC       LOINC Hierarchy                C
# 108  Measurement             LOINC       LOINC Hierarchy                C
# 109  Measurement             LOINC       LOINC Hierarchy                C
# 110  Measurement             LOINC       LOINC Hierarchy                C
# 111  Measurement             LOINC       LOINC Hierarchy                C
# 112  Measurement             LOINC       LOINC Hierarchy                C
# 113  Measurement             LOINC       LOINC Hierarchy                C
# 114  Measurement             LOINC       LOINC Hierarchy                C
# 115  Measurement             LOINC              Lab Test                S
# 116  Measurement             LOINC  Clinical Observation                S
# 117  Measurement             LOINC  Clinical Observation                S
#
#         concept_code valid_start_date valid_end_date invalid_reason
# 0               4193       1979-01-01     2099-01-01           None
# 1                788       1979-01-01     2099-01-01           None
# 2               5753       1979-01-01     2099-01-01           None
# 3               3747       1979-01-01     2099-01-01           None
# 4               1523       1979-01-01     2099-01-01           None
# 5               3578       1979-01-01     2099-01-01           None
# 6               3624       1979-01-01     2099-01-01           None
# 7              30296       1979-01-01     2099-01-01           None
# 8              30297       1979-01-01     2099-01-01           None
# 9              30300       1979-01-01     2099-01-01           None
# 10             30022       1979-01-01     2099-01-01           None
# 11            225166       1979-01-01     2099-01-01           None
# 12            228385       1979-01-01     2099-01-01           None
# 13            228386       1979-01-01     2099-01-01           None
# 14            220602       1979-01-01     2099-01-01           None
# 15            226536       1979-01-01     2099-01-01           None
# 16             50806       1979-01-01     2099-01-01           None
# 17             50839       1979-01-01     2099-01-01           None
# 18             50902       1979-01-01     2099-01-01           None
# 19             51013       1979-01-01     2099-01-01           None
# 20             51030       1979-01-01     2099-01-01           None
# 21             51050       1979-01-01     2099-01-01           None
# 22             51062       1979-01-01     2099-01-01           None
# 23             51078       1979-01-01     2099-01-01           None
# 24   792231000000102       2014-04-01     2099-12-31           None
# 25           1011335       2014-10-10     2099-12-31           None
# 26             80047       2008-04-01     2099-12-31           None
# 27             80048       1970-01-01     2099-12-31           None
# 28             80053       1970-01-01     2099-12-31           None
# 29             80051       1970-01-01     2099-12-31           None
# ..               ...              ...            ...            ...
# 88         LP46467-4       1970-01-01     2099-12-31           None
# 89         LP50363-8       1970-01-01     2099-12-31           None
# 90         LP42259-9       1970-01-01     2099-12-31           None
# 91         LP42860-4       1970-01-01     2099-12-31           None
# 92         LP50000-6       1970-01-01     2099-12-31           None
# 93         LP70655-3       1970-01-01     2099-12-31           None
# 94         LP51616-8       1970-01-01     2099-12-31           None
# 95         LP41734-2       1970-01-01     2099-12-31           None
# 96         LP42792-9       1970-01-01     2099-12-31           None
# 97         LP46442-7       1970-01-01     2099-12-31           None
# 98         LP46427-8       1970-01-01     2099-12-31           None
# 99         LP52289-3       1970-01-01     2099-12-31           None
# 100        LP51600-2       1970-01-01     2099-12-31           None
# 101        LP42059-3       1970-01-01     2099-12-31           None
# 102        LP15483-8       1970-01-01     2099-12-31           None
# 103       LP101154-5       1970-01-01     2099-12-31           None
# 104        LP46476-5       1970-01-01     2099-12-31           None
# 105        LP51401-5       1970-01-01     2099-12-31           None
# 106        LP43906-4       1970-01-01     2099-12-31           None
# 107        LP51441-1       1970-01-01     2099-12-31           None
# 108       LP100823-6       1970-01-01     2099-12-31           None
# 109        LP46460-9       1970-01-01     2099-12-31           None
# 110        LP52288-5       1970-01-01     2099-12-31           None
# 111        LP51827-1       1970-01-01     2099-12-31           None
# 112        LP70038-2       1970-01-01     2099-12-31           None
# 113        LP46464-1       1970-01-01     2099-12-31           None
# 114        LP46433-6       1970-01-01     2099-12-31           None
# 115          77138-6       2015-05-08     2099-12-31           None
# 116          81080-4       2016-06-24     2099-12-31           None
# 117          80983-0       2016-06-24     2099-12-31           None
#
# [118 rows x 10 columns]

# %% [markdown]
# # Filter your data

# %% [markdown]
# ## Limitations
# Starting with the limitations, we need to make sure our dataset only integrates people that do not originally depend on medical critical assistance equipment

# %%
query = """
select 
    concept_id, concept_code, domain_id, concept_name
from
    concept
where
    concept_id in (2001018843, 2001030812)
    ;"""

limitations = pd.read_sql_query(query, conn)
limitations
# Out:
#    concept_id concept_code    domain_id  \
# 0  2001018843          128  Measurement
# 1  2001030812       223758  Measurement
#
#                                         concept_name
# 0  label:[Code Status]dbsource:[carevue]linksto:[...
# 1  label:[Code Status]dbsource:[metavision]linkst...

# %% [markdown]
# People that were once not limited

# %%
query = """
select 
    count(distinct person_id)
from
    measurement
where
    measurement_type_concept_id = 44818701
    and measurement_concept_id = 4127294
    and value_source_value in ('Full code', 'Full Code')
    ;"""

temp = pd.read_sql_query(query, conn)
temp
# Out:
#       L3
# 0  30833

# %% [markdown]
# People that have been limited

# %%
query = """
select 
    person_id, min(measurement_datetime)
from
    measurement
where
    measurement_type_concept_id = 44818701
    and measurement_concept_id = 4127294
    and value_source_value in ('Full code', 'Full Code')
group by
    person_id
    ;"""

temp = pd.read_sql_query(query, conn)
temp
# Out:
# Index(['measurement_id', 'person_id', 'measurement_concept_id',
#        'measurement_concept_name', 'measurement_concept_code',
#        'measurement_concept_code_system', 'measurement_date',
#        'measurement_datetime', 'measurement_type_concept_id',
#        'measurement_type_concept_name', 'operator_concept_id',
#        'operator_concept_name', 'value_as_number', 'value_as_concept_id',
#        'unit_concept_id', 'unit_concept_name', 'unit_concept_code',
#        'unit_concept_code_system', 'range_low', 'range_high', 'provider_id',
#        'visit_occurrence_id', 'visit_detail_id', 'measurement_source_value',
#        'measurement_source_concept_id', 'unit_source_value',
#        'value_source_value'],
#       dtype='object')

# %%
query = """

select
    person_id, min(measurement_datetime) as first_limitation_datetime
from
    measurement
where
    measurement_id not in 
                            (select 
                                measurement_id
                            from
                                measurement
                            where
                                measurement_type_concept_id = 44818701
                                and measurement_concept_id = 4127294
                                and value_source_value in ('Full code', 'Full Code'))
group by
    person_id
limit 10
    ;"""

temp = pd.read_sql_query(query, conn)
temp
# Out:
#    person_id first_limitation_datetime
# 0   62105861       2117-09-11 08:22:00
# 1   62095228       2150-04-17 12:30:00
# 2   62073122       2108-04-06 11:30:00
# 3   62102210       2176-08-08 23:25:00
# 4   62080413       2145-03-30 21:15:00
# 5   62064070       2155-06-21 01:26:00
# 6   62085950       2109-08-17 04:30:00
# 7   62088661       2109-12-10 10:25:00
# 8   62106943       2177-08-29 03:35:00
# 9   62096723       2177-03-12 13:02:00

# %% [markdown]
# ## Age and ICU
# Moving to the next filters:
# - Age >= 15
# - Processed only by intensive care unit

# %%
query = """
select
    count(distinct p.person_id)
from 
    person p
    
    inner join

    (select 
        person_id, min(visit_start_date) as first_visit_date
    from
        visit_occurrence
    group by 
        person_id) v
    
    on p.person_id = v.person_id
    
where
    (v.first_visit_date - p.birth_datetime) >= 15 * 365.25
    and p.person_id in (select
                            person_id
                        from
                            visit_detail
                        where
                            visit_detail_concept_id = 581382
                            and visit_type_concept_id = 2000000006)
    ;"""

temp = pd.read_sql_query(query, conn)
temp
# Out:
#      L11
# 0  38604

# %% [markdown]
# ## Fleming filter

# %%
query = """
select
    count(distinct p.person_id)
from 
    person p
    
    inner join

    (select 
        person_id, min(visit_start_date) as first_visit_date
    from
        visit_occurrence
    group by 
        person_id) v
    
    on p.person_id = v.person_id
    
where
    (v.first_visit_date - p.birth_datetime) >= 15 * 365.25
    and p.person_id not in (select 
                                distinct person_id
                            from
                                measurement
                            where
                                not(measurement_type_concept_id = 44818701
                                and measurement_concept_id = 4127294
                                and value_source_value in ('Full code', 'Full Code')))
    ;"""

temp = pd.read_sql_query(query, conn)
temp
# Out:
#    L25
# 0    0
